# %% [markdown]
# ### Swedish demographic

# %%
import numpy as np
import pandas as pd

tables = pd.read_html("https://sv.wikipedia.org/wiki/Sveriges_demografi")
len(tables)
# Out:
# 21

# %%
tables[3]
# Out:
#                       Antal födda och döda i Sverige
# 0  Se eller redigera rådata. Antal födda (blått) ...

# %%
tables[6]
# Out:
#      Unnamed: 0 Medel- folkmängd    Födda    Döda  \
# 0          1900        5 117 000  138 139  86 146
# 1          1901        5 156 000  139 370  82 772
# 2          1902        5 187 000  137 364  79 722
# 3          1903        5 210 000  133 896  78 610
# 4          1904        5 241 000  134 952  80 152
# ..          ...              ...      ...     ...
# 118        2018     10 175 213,5  115 832  92 185
# 119        2019     10 278 887,0  114 523  88 766
# 120        2020     10 353 442,0  113 077  98 124
# 121        2021     10 415 810,5  114 263  91 958
# 122        2022              NaN  104 734  94 737
#
#     Naturlig befolknings- förändring  Nativitet (per 1000)  \
# 0                             51 993                 270.0
# 1                             56 598                 270.0
# 2                             57 642                 265.0
# 3                             55 286                 257.0
# 4                             54 800                 257.0
# ...
