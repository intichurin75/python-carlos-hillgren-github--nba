# %% [markdown]
# ### Code AlongS API

# %%
from dotenv import load_dotenv
import requests
import pandas as pd
import os

load_dotenv()
api_key = os.getenv("ALPHA_API_KEY")

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey={api_key}'
r = requests.get(url)
data = r.json()

data.keys()
# Out:
# dict_keys(['Meta Data', 'Time Series (Daily)'])

# %%
data["Meta Data"]
# Out:
# {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#  '2. Symbol': 'IBM',
#  '3. Last Refreshed': '2024-03-20',
#  '4. Output Size': 'Compact',
#  '5. Time Zone': 'US/Eastern'}

# %%
data["Time Series (Daily)"]
# Out:
# {'2024-03-20': {'1. open': '192.8700',
#   '2. high': '193.9800',
#   '3. low': '191.3100',
#   '4. close': '193.9600',
#   '5. volume': '3238643'},
#  '2024-03-19': {'1. open': '191.4900',
#   '2. high': '193.5800',
#   '3. low': '190.2800',
#   '4. close': '193.3400',
#   '5. volume': '5317341'},
#  '2024-03-18': {'1. open': '191.7000',
#   '2. high': '193.2300',
#   '3. low': '190.3200',
#   '4. close': '191.6900',
#   '5. volume': '5410562'},
#  '2024-03-15': {'1. open': '191.9900',
#   '2. high': '193.0573',
#   '3. low': '190.7000',
#   '4. close': '191.0700',
#   '5. volume': '8828184'},
#  '2024-03-14': {'1. open': '196.9500',
#   '2. high': '197.7480',
#   '3. low': '192.1200',
#   '4. close': '193.4300',
#   '5. volume': '4102202'},
#  '2024-03-13': {'1. open': '197.5500',
#   '2. high': '198.1000',
#   '3. low': '195.3200',
#   '4. close': '196.7000',
#   '5. volume': '3960737'},
#  '2024-03-12': {'1. open': '192.4600',
#   '2. high': '199.1800',
#   '3. low': '192.1500',
#   '4. close': '197.7800',
#   '5. volume': '5862512'},
#  '2024-03-11': {'1. open': '195.0900',
#   '2. high': '195.3800',
#   '3. low': '190.8800',
#   '4. close': '191.7300',
#   '5. volume': '4712688'},
#  '2024-03-08': {'1. open': '196.0600',
#   '2. high': '197.7700',
#   '3. low': '194.3800',
#   '4. close': '195.9500',
#   '5. volume': '3943113'},
#  '2024-03-07': {'1. open': '197.5800',
#   '2. high': '198.7300',
#   '3. low': '196.1400',
#   '4. close': '196.5400',
#   '5. volume': '4604458'},
#  '2024-03-06': {'1. open': '193.5000',
#   '2. high': '198.1300',
#   '3. low': '192.9600',
#   '4. close': '196.1600',
#   '5. volume': '6945818'},
#  '2024-03-05': {'1. open': '192.0000',
#   '2. high': '193.9400',
#   '3. low': '190.5700',
#   '4. close': '191.9500',
#   '5. volume': '5653641'},
#  '2024-03-04': {'1. open': '187.7600',
#   '2. high': '193.8980',
#   '3. low': '187.6000',
#   '4. close': '193.0600',
#   '5. volume': '7938266'},
#  '2024-03-01': {'1. open': '185.4900',
#   '2. high': '188.3800',
#   '3. low': '185.1800',
#   '4. close': '188.2000',
#   '5. volume': '4018354'},
#  '2024-02-29': {'1. open': '186.1500',
#   '2. high': '186.8495',
#   '3. low': '184.6900',
#   '4. close': '185.0300',
#   '5. volume': '6458487'},
#  '2024-02-28': {'1. open': '184.6300',
#   '2. high': '185.3700',
#   '3. low': '183.5500',
#   '4. close': '185.3000',
#   '5. volume': '3216345'},
#  '2024-02-27': {'1. open': '184.1600',
#   '2. high': '185.1300',
#   '3. low': '182.6200',
#   '4. close': '184.8700',
#   '5. volume': '3641378'},
#  '2024-02-26': {'1. open': '185.6000',
#   '2. high': '186.1250',
#   '3. low': '184.0600',
#   '4. close': '184.1300',
#   '5. volume': '4620815'},
#  '2024-02-23': {'1. open': '184.9000',
#   '2. high': '186.4550',
#   '3. low': '184.5700',
#   '4. close': '185.7200',
#   '5. volume': '3433800'},
#  '2024-02-22': {'1. open': '182.4500',
#   '2. high': '184.5500',
#   '3. low': '181.9300',
#   '4. close': '184.2100',
#   '5. volume': '5078398'},
#  '2024-02-21': {'1. open': '182.5600',
#   '2. high': '183.0300',
#   '3. low': '178.7500',
#   '4. close': '179.7000',
#   '5. volume': '4728473'},
#  '2024-02-20': {'1. open': '187.6400',
#   '2. high': '188.7700',
#   '3. low': '183.0600',
#   '4. close': '183.4400',
#   '5. volume': '4247181'},
#  '2024-02-16': {'1. open': '186.6300',
#   '2. high': '188.9500',
#   '3. low': '185.9452',
#   '4. close': '187.6400',
#   '5. volume': '4842840'},
#  '2024-02-15': {'1. open': '183.6200',
#   '2. high': '186.9800',
#   '3. low': '183.6200',
#   '4. close': '186.8700',
#   '5. volume': '4714301'},
#  '2024-02-14': {'1. open': '185.0000',
#   '2. high': '185.0000',
#   '3. low': '182.2600',
#   '4. close': '183.5700',
#   '5. volume': '3173391'},
#  '2024-02-13': {'1. open': '184.2800',
#   '2. high': '184.7700',
#   '3. low': '182.3600',
#   '4. close': '183.7000',
#   '5. volume': '4290453'},
#  '2024-02-12': {'1. open': '185.9000',
#   '2. high': '186.4800',
#   '3. low': '184.0300',
#   '4. close': '186.1600',
#   '5. volume': '4724021'},
#  '2024-02-09': {'1. open': '184.4400',
#   '2. high': '187.1800',
#   '3. low': '183.8500',
#   '4. close': '186.3400',
#   '5. volume': '5064641'},
#  '2024-02-08': {'1. open': '182.6300',
#   '2. high': '184.5500',
#   '3. low': '181.4900',
#   '4. close': '184.3600',
#   '5. volume': '5161185'},
#  '2024-02-07': {'1. open': '183.3400',
#   '2. high': '184.0200',
#   '3. low': '182.6250',
#   '4. close': '183.7400',
#   '5. volume': '4841188'},
#  '2024-02-06': {'1. open': '183.5500',
#   '2. high': '184.6800',
#   '3. low': '183.0400',
#   '4. close': '183.4100',
#   '5. volume': '3338196'},
#  '2024-02-05': {'1. open': '185.5100',
#   '2. high': '185.7800',
#   '3. low': '183.2550',
#   '4. close': '183.4200',
#   '5. volume': '4379602'},
#  '2024-02-02': {'1. open': '187.1000',
#   '2. high': '187.3900',
#   '3. low': '185.6150',
#   '4. close': '185.7900',
#   '5. volume': '4055411'},
#  '2024-02-01': {'1. open': '183.6300',
#   '2. high': '187.5100',
#   '3. low': '182.7100',
#   '4. close': '186.9000',
#   '5. volume': '4669444'},
#  '2024-01-31': {'1. open': '187.0500',
#   '2. high': '187.6500',
#   '3. low': '183.1400',
#   '4. close': '183.6600',
#   '5. volume': '8876055'},
#  '2024-01-30': {'1. open': '187.7100',
#   '2. high': '188.6500',
#   '3. low': '186.7700',
#   '4. close': '187.8700',
#   '5. volume': '4575058'},
#  '2024-01-29': {'1. open': '187.4600',
#   '2. high': '189.4600',
#   '3. low': '186.0500',
#   '4. close': '187.1400',
#   '5. volume': '6107908'},
#  '2024-01-26': {'1. open': '191.3100',
#   '2. high': '192.3896',
#   '3. low': '186.1600',
#   '4. close': '187.4200',
#   '5. volume': '9895941'},
#  '2024-01-25': {'1. open': '184.9600',
#   '2. high': '196.9000',
#   '3. low': '184.8300',
#   '4. close': '190.4300',
#   '5. volume': '29596239'},
#  '2024-01-24': {'1. open': '174.7600',
#   '2. high': '174.8600',
#   '3. low': '172.9000',
#   '4. close': '173.9300',
#   '5. volume': '7831157'},
#  '2024-01-23': {'1. open': '172.9000',
#   '2. high': '174.0200',
#   '3. low': '172.4800',
#   '4. close': '173.9400',
#   '5. volume': '3983461'},
#  '2024-01-22': {'1. open': '172.8200',
#   '2. high': '174.4500',
#   '3. low': '172.4000',
#   '4. close': '172.8300',
#   '5. volume': '4925964'},
#  '2024-01-19': {'1. open': '170.5900',
#   '2. high': '171.5791',
#   '3. low': '169.1800',
#   '4. close': '171.4800',
#   '5. volume': '6929079'},
#  '2024-01-18': {'1. open': '166.4900',
#   '2. high': '166.9900',
#   '3. low': '165.0400',
#   '4. close': '166.8400',
#   '5. volume': '3776990'},
#  '2024-01-17': {'1. open': '166.7900',
#   '2. high': '167.8200',
#   '3. low': '165.4950',
#   '4. close': '166.0800',
#   '5. volume': '4288604'},
#  '2024-01-16': {'1. open': '165.8000',
#   '2. high': '167.2500',
#   '3. low': '165.3400',
#   '4. close': '166.9600',
#   '5. volume': '4869635'},
#  '2024-01-12': {'1. open': '162.9700',
#   '2. high': '165.9800',
#   '3. low': '162.3550',
#   '4. close': '165.8000',
#   '5. volume': '4958261'},
#  '2024-01-11': {'1. open': '161.0200',
#   '2. high': '162.2300',
#   '3. low': '160.2900',
#   '4. close': '162.1600',
#   '5. volume': '3778395'},
#  '2024-01-10': {'1. open': '160.2800',
#   '2. high': '161.3400',
#   '3. low': '159.7400',
#   '4. close': '161.2300',
#   '5. volume': '2967852'},
#  '2024-01-09': {'1. open': '160.0000',
#   '2. high': '160.4837',
#   '3. low': '159.5100',
#   '4. close': '160.0800',
#   '5. volume': '2617186'},
#  '2024-01-08': {'1. open': '158.6900',
#   '2. high': '161.2160',
#   '3. low': '157.8850',
#   '4. close': '161.1400',
#   '5. volume': '3321698'},
#  '2024-01-05': {'1. open': '159.9100',
#   '2. high': '160.5500',
#   '3. low': '158.6700',
#   '4. close': '159.1600',
#   '5. volume': '3698961'},
#  '2024-01-04': {'1. open': '160.2200',
#   '2. high': '161.8100',
#   '3. low': '160.1700',
#   '4. close': '160.8600',
#   '5. volume': '3212004'},
#  '2024-01-03': {'1. open': '161.0000',
#   '2. high': '161.7300',
#   '3. low': '160.0800',
#   '4. close': '160.1000',
#   '5. volume': '4086065'},
#  '2024-01-02': {'1. open': '162.8300',
#   '2. high': '163.2900',
#   '3. low': '160.4600',
#   '4. close': '161.5000',
#   '5. volume': '3825044'},
#  '2023-12-29': {'1. open': '163.7500',
#   '2. high': '164.1800',
#   '3. low': '162.8300',
#   '4. close': '163.5500',
#   '5. volume': '2526169'},
#  '2023-12-28': {'1. open': '163.9600',
#   '2. high': '163.9600',
#   '3. low': '163.4000',
#   '4. close': '163.7500',
#   '5. volume': '2071313'},
#  '2023-12-27': {'1. open': '163.1400',
#   '2. high': '163.6400',
#   '3. low': '162.6800',
#   '4. close': '163.4600',
#   '5. volume': '3006612'},
#  '2023-12-26': {'1. open': '162.2300',
#   '2. high': '163.3100',
#   '3. low': '162.0500',
#   '4. close': '163.2100',
#   '5. volume': '1772443'},
#  '2023-12-22': {'1. open': '161.1000',
#   '2. high': '162.4100',
#   '3. low': '161.0000',
#   '4. close': '162.1400',
#   '5. volume': '2442715'},
#  '2023-12-21': {'1. open': '160.5900',
#   '2. high': '161.0800',
#   '3. low': '159.5300',
#   '4. close': '160.7800',
#   '5. volume': '2982924'},
#  '2023-12-20': {'1. open': '161.2900',
#   '2. high': '161.8000',
#   '3. low': '160.0100',
#   '4. close': '160.0500',
#   '5. volume': '4865797'},
#  '2023-12-19': {'1. open': '161.8000',
#   '2. high': '162.2800',
#   '3. low': '161.3200',
#   '4. close': '161.5600',
#   '5. volume': '3717429'},
#  '2023-12-18': {'1. open': '162.2300',
#   '2. high': '163.3300',
#   '3. low': '161.5766',
#   '4. close': '162.7400',
#   '5. volume': '3677533'},
#  '2023-12-15': {'1. open': '162.3000',
#   '2. high': '164.0900',
#   '3. low': '162.0400',
#   '4. close': '162.2300',
#   '5. volume': '11016108'},
#  '2023-12-14': {'1. open': '162.9300',
#   '2. high': '163.4990',
#   '3. low': '160.1490',
#   '4. close': '162.9100',
#   '5. volume': '6129804'},
#  '2023-12-13': {'1. open': '164.3700',
#   '2. high': '164.9653',
#   '3. low': '162.7350',
#   '4. close': '163.6200',
#   '5. volume': '4989141'},
#  '2023-12-12': {'1. open': '163.2700',
#   '2. high': '166.3400',
#   '3. low': '162.9200',
#   '4. close': '164.7100',
#   '5. volume': '5292290'},
#  '2023-12-11': {'1. open': '162.6800',
#   '2. high': '163.6500',
#   '3. low': '161.9500',
#   '4. close': '163.5100',
#   '5. volume': '6077207'},
#  '2023-12-08': {'1. open': '160.0000',
#   '2. high': '162.0400',
#   '3. low': '160.0000',
#   '4. close': '161.9600',
#   '5. volume': '4561342'},
#  '2023-12-07': {'1. open': '161.0000',
#   '2. high': '161.4650',
#   '3. low': '159.9700',
#   '4. close': '160.2200',
#   '5. volume': '3665498'},
#  '2023-12-06': {'1. open': '161.5900',
#   '2. high': '162.3550',
#   '3. low': '160.0100',
#   '4. close': '160.2800',
#   '5. volume': '3356432'},
#  '2023-12-05': {'1. open': '160.7600',
#   '2. high': '162.4700',
#   '3. low': '160.7200',
#   '4. close': '161.3900',
#   '5. volume': '4556668'},
#  '2023-12-04': {'1. open': '160.2900',
#   '2. high': '162.7900',
#   '3. low': '160.2900',
#   '4. close': '161.1000',
#   '5. volume': '5779017'},
#  '2023-12-01': {'1. open': '158.4100',
#   '2. high': '160.5900',
#   '3. low': '158.0000',
#   '4. close': '160.5500',
#   '5. volume': '4871860'},
#  '2023-11-30': {'1. open': '156.9500',
#   '2. high': '158.6000',
#   '3. low': '156.8900',
#   '4. close': '158.5600',
#   '5. volume': '6740622'},
#  '2023-11-29': {'1. open': '156.1500',
#   '2. high': '157.5100',
#   '3. low': '156.0200',
#   '4. close': '156.4100',
#   '5. volume': '3568887'},
#  '2023-11-28': {'1. open': '155.4400',
#   '2. high': '155.7450',
#   '3. low': '154.8600',
#   '4. close': '155.6500',
#   '5. volume': '2666182'},
#  '2023-11-27': {'1. open': '154.9900',
#   '2. high': '156.1350',
#   '3. low': '154.7500',
#   '4. close': '155.5700',
#   '5. volume': '4053093'},
#  '2023-11-24': {'1. open': '155.1300',
#   '2. high': '155.4000',
#   '3. low': '153.9200',
#   '4. close': '155.1800',
#   '5. volume': '1799161'},
#  '2023-11-22': {'1. open': '154.5000',
#   '2. high': '155.7050',
#   '3. low': '154.1600',
#   '4. close': '155.1300',
#   '5. volume': '3045091'},
#  '2023-11-21': {'1. open': '154.6000',
#   '2. high': '154.6600',
#   '3. low': '153.5100',
#   '4. close': '153.9100',
#   '5. volume': '2859508'},
#  '2023-11-20': {'1. open': '152.5100',
#   '2. high': '154.6800',
#   '3. low': '152.3500',
#   '4. close': '154.3500',
#   '5. volume': '3658936'},
#  '2023-11-17': {'1. open': '153.2900',
#   '2. high': '153.5000',
#   '3. low': '152.4601',
#   '4. close': '152.8900',
#   '5. volume': '4426676'},
#  '2023-11-16': {'1. open': '153.0000',
#   '2. high': '153.3500',
#   '3. low': '152.1300',
#   '4. close': '153.0600',
#   '5. volume': '3519172'},
#  '2023-11-15': {'1. open': '150.4000',
#   '2. high': '153.2200',
#   '3. low': '150.4000',
#   '4. close': '152.5800',
#   '5. volume': '4632519'},
#  '2023-11-14': {'1. open': '149.4500',
#   '2. high': '150.8063',
#   '3. low': '149.0500',
#   '4. close': '150.4100',
#   '5. volume': '4321940'},
#  '2023-11-13': {'1. open': '148.4600',
#   '2. high': '148.4900',
#   '3. low': '147.3500',
#   '4. close': '148.1000',
#   '5. volume': '2647288'},
#  '2023-11-10': {'1. open': '147.4400',
#   '2. high': '149.1700',
#   '3. low': '146.8500',
#   '4. close': '149.0200',
#   '5. volume': '3179541'},
#  '2023-11-09': {'1. open': '146.5500',
#   '2. high': '146.9900',
#   '3. low': '145.2800',
#   '4. close': '146.6200',
#   '5. volume': '3412713'},
#  '2023-11-08': {'1. open': '149.2500',
#   '2. high': '149.6800',
#   '3. low': '147.5850',
#   '4. close': '148.0300',
#   '5. volume': '3618588'},
#  '2023-11-07': {'1. open': '149.0300',
#   '2. high': '149.2800',
#   '3. low': '148.0300',
#   '4. close': '148.8300',
#   '5. volume': '3549853'},
#  '2023-11-06': {'1. open': '147.8900',
#   '2. high': '149.2250',
#   '3. low': '147.8500',
#   '4. close': '148.9700',
#   '5. volume': '4597249'},
#  '2023-11-03': {'1. open': '147.4500',
#   '2. high': '148.4450',
#   '3. low': '147.2800',
#   '4. close': '147.9000',
#   '5. volume': '3510495'},
#  '2023-11-02': {'1. open': '145.7700',
#   '2. high': '147.1000',
#   '3. low': '144.8400',
#   '4. close': '147.0100',
#   '5. volume': '3902657'},
#  '2023-11-01': {'1. open': '145.0000',
#   '2. high': '146.5100',
#   '3. low': '144.4500',
#   '4. close': '145.4000',
#   '5. volume': '4750081'},
#  '2023-10-31': {'1. open': '143.0000',
#   '2. high': '144.7600',
#   '3. low': '142.5900',
#   '4. close': '144.6400',
#   '5. volume': '6592041'},
#  '2023-10-30': {'1. open': '143.1900',
#   '2. high': '144.5000',
#   '3. low': '142.5800',
#   '4. close': '142.6300',
#   '5. volume': '4204190'},
#  '2023-10-27': {'1. open': '143.6200',
#   '2. high': '144.7000',
#   '3. low': '141.7100',
#   '4. close': '142.5200',
#   '5. volume': '5469227'},
#  '2023-10-26': {'1. open': '142.2000',
#   '2. high': '144.4100',
#   '3. low': '141.5800',
#   '4. close': '143.7600',
#   '5. volume': '11130170'}}

# %%
data["Time Series (Daily)"]["2024-03-18"]
# Out:
# {'1. open': '191.7000',
#  '2. high': '193.2300',
#  '3. low': '190.3200',
#  '4. close': '191.6900',
#  '5. volume': '5410562'}

# %%
data["Time Series (Daily)"]["2024-03-18"]["5. volume"]
# Out:
# '5410562'

# %%
pd.DataFrame(data["Time Series (Daily)"])
# Out:
#           2024-03-20 2024-03-19 2024-03-18 2024-03-15 2024-03-14 2024-03-13  \
# 1. open     192.8700   191.4900   191.7000   191.9900   196.9500   197.5500
# 2. high     193.9800   193.5800   193.2300   193.0573   197.7480   198.1000
# 3. low      191.3100   190.2800   190.3200   190.7000   192.1200   195.3200
# 4. close    193.9600   193.3400   191.6900   191.0700   193.4300   196.7000
# 5. volume    3238643    5317341    5410562    8828184    4102202    3960737
#
#           2024-03-12 2024-03-11 2024-03-08 2024-03-07  ... 2023-11-08  \
# 1. open     192.4600   195.0900   196.0600   197.5800  ...   149.2500
# 2. high     199.1800   195.3800   197.7700   198.7300  ...   149.6800
# 3. low      192.1500   190.8800   194.3800   196.1400  ...   147.5850
# 4. close    197.7800   191.7300   195.9500   196.5400  ...   148.0300
# 5. volume    5862512    4712688    3943113    4604458  ...    3618588
#
#           2023-11-07 2023-11-06 2023-11-03 2023-11-02 2023-11-01 2023-10-31  \
# 1. open     149.0300   147.8900   147.4500   145.7700   145.0000   143.0000
# 2. high     149.2800   149.2250   148.4450   147.1000   146.5100   144.7600
# 3. low      148.0300   147.8500   147.2800   144.8400   144.4500   142.5900
# 4. close    148.8300   148.9700   147.9000   147.0100   145.4000   144.6400
# 5. volume    3549853    4597249    3510495    3902657    4750081    6592041
#
#           2023-10-30 2023-10-27 2023-10-26
# 1. open     143.1900   143.6200   142.2000
# 2. high     144.5000   144.7000   144.4100
# 3. low      142.5800   141.7100   141.5800
# 4. close    142.6300   142.5200   143.7600
# 5. volume    4204190    5469227   11130170
#
# [5 rows x 100 columns]

# %%
pd.DataFrame(data["Time Series (Daily)"]).transpose()
# Out:
#              1. open   2. high    3. low  4. close 5. volume
# 2024-03-20  192.8700  193.9800  191.3100  193.9600   3238643
# 2024-03-19  191.4900  193.5800  190.2800  193.3400   5317341
# 2024-03-18  191.7000  193.2300  190.3200  191.6900   5410562
# 2024-03-15  191.9900  193.0573  190.7000  191.0700   8828184
# 2024-03-14  196.9500  197.7480  192.1200  193.4300   4102202
# ...              ...       ...       ...       ...       ...
# 2023-11-01  145.0000  146.5100  144.4500  145.4000   4750081
# 2023-10-31  143.0000  144.7600  142.5900  144.6400   6592041
# 2023-10-30  143.1900  144.5000  142.5800  142.6300   4204190
# 2023-10-27  143.6200  144.7000  141.7100  142.5200   5469227
# 2023-10-26  142.2000  144.4100  141.5800  143.7600  11130170
#
# [100 rows x 5 columns]

# %% [markdown]
# #### Iterate over several stocks

# %%
symbols = ["AAPL","NVDA","TSLA","IBM"]
stocklist = []

for symbol in symbols:
    url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={symbol}&apikey={api_key}'
    data = requests.get(url).json()
    df = pd.DataFrame(data["Time Series (Daily)"]).transpose()
    series = df["4. close"].rename(symbol).astype(float)
    stocklist.append(series)

# %%
stocklist[0]
# Out:
# 2024-03-20    178.67
# 2024-03-19    176.08
# 2024-03-18    173.72
# 2024-03-15    172.62
# 2024-03-14    173.00
#                ...
# 2023-11-01    173.97
# 2023-10-31    170.77
# 2023-10-30    170.29
# 2023-10-27    168.22
# 2023-10-26    166.89
# Name: AAPL, Length: 100, dtype: float64

# %%
len(stocklist)
# Out:
# 4

# %%
stocks = pd.concat(stocklist,axis=1) # pd.concat skapades först innan skapandet av variabel
stocks
# Out:
#               AAPL     NVDA    TSLA     IBM
# 2024-03-20  178.67  903.720  175.66  193.96
# 2024-03-19  176.08  893.980  171.32  193.34
# 2024-03-18  173.72  884.550  173.80  191.69
# 2024-03-15  172.62  878.365  163.57  191.07
# 2024-03-14  173.00  879.440  162.50  193.43
# ...            ...      ...     ...     ...
# 2023-11-01  173.97  423.250  205.66  145.40
# 2023-10-31  170.77  407.800  200.84  144.64
# 2023-10-30  170.29  411.610  197.36  142.63
# 2023-10-27  168.22  405.000  207.30  142.52
# 2023-10-26  166.89  403.260  205.76  143.76
#
# [100 rows x 4 columns]

# %%
import plotly_express as px
px.line(stocks, x=stocks.index, y=stocks.columns)

# %% [markdown]
# ### Working with time series

# %%
print(stocks.index.dtype)
stocks.index = pd.to_datetime(stocks.index)
print(stocks.index.dtype)
stocks.head()
# Out:
# object
# datetime64[ns]
#               AAPL     NVDA    TSLA     IBM
# 2024-03-20  178.67  903.720  175.66  193.96
# 2024-03-19  176.08  893.980  171.32  193.34
# 2024-03-18  173.72  884.550  173.80  191.69
# 2024-03-15  172.62  878.365  163.57  191.07
# 2024-03-14  173.00  879.440  162.50  193.43

# %%
stocks.loc["2023-11"]
# Out:
#               AAPL    NVDA    TSLA     IBM
# 2023-11-30  189.95  467.70  240.08  158.56
# 2023-11-29  189.37  481.40  244.14  156.41
# 2023-11-28  190.40  478.21  246.72  155.65
# 2023-11-27  189.79  482.42  236.08  155.57
# 2023-11-24  189.97  477.76  235.45  155.18
# 2023-11-22  191.31  487.16  234.21  155.13
# 2023-11-21  190.64  499.44  241.20  153.91
# 2023-11-20  191.45  504.09  235.60  154.35
# 2023-11-17  189.69  492.98  234.30  152.89
# 2023-11-16  189.71  494.80  233.59  153.06
# 2023-11-15  188.01  488.88  242.84  152.58
# 2023-11-14  187.44  496.56  237.41  150.41
# 2023-11-13  184.80  486.20  223.71  148.10
# 2023-11-10  186.40  483.35  214.65  149.02
# 2023-11-09  182.41  469.50  209.98  146.62
# 2023-11-08  182.89  465.74  222.11  148.03
# 2023-11-07  181.82  459.55  222.18  148.83
# 2023-11-06  179.23  457.51  219.27  148.97
# 2023-11-03  176.65  450.05  219.96  147.90
# 2023-11-02  177.57  435.06  218.51  147.01
# 2023-11-01  173.97  423.25  205.66  145.40

# %%
stocks.sort_index().loc["2024-02":"2024-03"]
# Out:
#               AAPL     NVDA    TSLA     IBM
# 2024-02-01  186.86  630.270  188.86  186.90
# 2024-02-02  185.85  661.600  187.91  185.79
# 2024-02-05  187.68  693.320  181.06  183.42
# 2024-02-06  189.30  682.230  185.10  183.41
# 2024-02-07  189.41  700.990  187.58  183.74
# 2024-02-08  188.32  696.410  189.56  184.36
# 2024-02-09  188.85  721.330  193.57  186.34
# 2024-02-12  187.15  722.480  188.13  186.16
# 2024-02-13  185.04  721.280  184.02  183.70
# 2024-02-14  184.15  739.000  188.71  183.57
# 2024-02-15  183.86  726.580  200.45  186.87
# 2024-02-16  182.31  726.130  199.95  187.64
# 2024-02-20  181.56  694.520  193.76  183.44
# 2024-02-21  182.32  674.720  194.77  179.70
# 2024-02-22  184.37  785.380  197.41  184.21
# 2024-02-23  182.52  788.170  191.97  185.72
# 2024-02-26  181.16  790.920  199.40  184.13
# 2024-02-27  182.63  787.010  199.73  184.87
# 2024-02-28  181.42  776.630  202.04  185.30
# 2024-02-29  180.75  791.120  201.88  185.03
# 2024-03-01  179.66  822.790  202.64  188.20
# 2024-03-04  175.10  852.370  188.14  193.06
# 2024-03-05  170.12  859.640  180.74  191.95
# 2024-03-06  169.12  887.000  176.54  196.16
# 2024-03-07  169.00  926.690  178.65  196.54
# 2024-03-08  170.73  875.280  175.34  195.95
# 2024-03-11  172.75  857.740  177.77  191.73
# 2024-03-12  173.23  919.130  177.54  197.78
# 2024-03-13  171.13  908.880  169.48  196.70
# 2024-03-14  173.00  879.440  162.50  193.43
# 2024-03-15  172.62  878.365  163.57  191.07
# 2024-03-18  173.72  884.550  173.80  191.69
# 2024-03-19  176.08  893.980  171.32  193.34
# 2024-03-20  178.67  903.720  175.66  193.96

# %% [markdown]
# ### Plot 4 stocks in subplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fix,axes = plt.subplots(2,2)
axes
# Out:
# array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)

# %%
axes.shape
# Out:
# (2, 2)

# %%
axes.flatten()
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
axes.flatten(), axes.flatten().shape
# Out:
# (array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object), (4,))

# %%
fix,axes = plt.subplots(2,2,dpi=100, figsize=(12,6))
stock_Names = {"AAPL" : "Apple", "NVDA": "Nvidia","TSLA": "Tesla", "IBM":"IBM"}

for ax, symbol in zip(axes.flatten(), stock_Names):
    sns.lineplot(data=stocks, x=stocks.index,y= symbol, ax=ax)
    ax.set (title=f"{stock_Names[symbol]}")

fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 9
#       5     sns.lineplot(data=stocks, x=stocks.index,y= symbol, ax=ax)
#       6     ax.set (title=f"{stock_Names[symbol]}")
# ----> 9 fig.tight_layout()
#
# NameError: name 'fig' is not defined
